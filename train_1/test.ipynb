# %%
# Importing the required libraries
from ultralytics import YOLO
import squarify
import matplotlib.pyplot as plt
import cv2
import os
import random
import pandas as pd
import matplotlib.image as mpimg
import seaborn as sns
import torch

sns.set_style('darkgrid')

# %matplotlib inline

# %%
# Function to perform person detections
def person_detect(img_path):
    
    # Read the image
    img = cv2.imread(img_path)

    # Pass the image through the detection model and get the result
    detect_result = model(img)

    # Plot the detections
    detect_img = detect_result[0].plot()
    
    # Convert the image to RGB format
    detect_img = cv2.cvtColor(detect_img, cv2.COLOR_BGR2RGB)
    
    return detect_img

# %%
import random

# Define the directory where the custom images are stored
custom_image_dir = '../data/test/images'

# Get the list of image files in the directory
image_files = os.listdir(custom_image_dir)

# Select 16 random images from the list
selected_images = random.sample(image_files, 16)

# Create a figure with subplots for each image
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(15, 15))

# Iterate over the selected images and plot each one
for i, img_file in enumerate(selected_images):
        
    # Compute the row and column index of the current subplot
    row_idx = i // 4
    col_idx = i % 4
    
    # Load the current image and run object detection
    img_path = os.path.join(custom_image_dir, img_file)
    detect_img = person_detect(img_path)
    
    # Plot the current image on the appropriate subplot
    axes[row_idx, col_idx].imshow(detect_img)
    axes[row_idx, col_idx].axis('off')

# Adjust the spacing between the subplots
plt.subplots_adjust(wspace=0.05, hspace=0.05)
# Out:
# 0: 640x640 1 sit, 269.4ms
# Speed: 10.8ms preprocess, 269.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 stand, 216.7ms
# Speed: 10.8ms preprocess, 216.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 stand, 204.6ms
# Speed: 6.6ms preprocess, 204.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 lie, 1 sit, 86.3ms
# Speed: 9.8ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 lie, 85.9ms
# Speed: 2.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 stand, 85.3ms
# Speed: 4.4ms preprocess, 85.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 lie, 81.7ms
# Speed: 0.0ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 stand, 82.7ms
# Speed: 5.8ms preprocess, 82.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 stand, 72.8ms
# Speed: 3.7ms preprocess, 72.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 lie, 71.3ms
# Speed: 2.5ms preprocess, 71.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 sit, 81.4ms
# Speed: 4.7ms preprocess, 81.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 sits, 4 stands, 77.8ms
# Speed: 5.1ms preprocess, 77.8ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 lies, 76.1ms
# Speed: 2.6ms preprocess, 76.1ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 stand, 82.4ms
# Speed: 2.0ms preprocess, 82.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 sit, 81.1ms
# Speed: 2.1ms preprocess, 81.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 sit, 80.4ms
# Speed: 2.9ms preprocess, 80.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
